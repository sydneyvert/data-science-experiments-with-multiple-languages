# %%
import pickle
with open('../data/data.pickle', 'rb') as f:
  data = pickle.load(f)

# %%
words = data['extrawordsplit']

# %%
data
# Out:
#                 original       specialcharsplit           extrawordsplit  \
# 0             V76szXAoQ9     [V, 76, szXAoQ, 9]   [v, 76, sz, xao, q, 9]
# 1              milanek22          [milanek, 22]          [milan, ek, 22]
# 2           PancharT1983       [PancharT, 1983]       [pan, chart, 1983]
# 3             pipinka123         [pipinka, 123]       [pi, pink, a, 123]
# 4                bulldog              [bulldog]                [bulldog]
# 5      nereknu9558285913  [nereknu, 9558285913]  [nere, knu, 9558285913]
# 6                blbysek              [blbysek]            [bl, by, sek]
# 7               123456a7         [123456, a, 7]           [123456, a, 7]
# 8              lumpy1976          [lumpy, 1976]            [lumpy, 1976]
# 9                simonm4            [simonm, 4]            [simon, m, 4]
# 10              kurvicky             [kurvicky]             [kur, vicky]
# 11            MlGqTAZY05         [MlGqTAZY, 05]           [mlgqtazy, 05]
# ...

# %% [markdown]
# import enchant
# d = enchant.Dict("en_US")
# d.check("Hello")

# %%
for index, row in data.iterrows():
    for i, val in enumerate(row['extrawordsplit']):
        if len((row['extrawordsplit'])[i]) == 2:
            (row['extrawordsplit'])[i] = ''

# %%
data
# Out:
#                 original       specialcharsplit           extrawordsplit  \
# 0             V76szXAoQ9     [V, 76, szXAoQ, 9]       [v, , , xao, q, 9]
# 1              milanek22          [milanek, 22]              [milan, , ]
# 2           PancharT1983       [PancharT, 1983]       [pan, chart, 1983]
# 3             pipinka123         [pipinka, 123]         [, pink, a, 123]
# 4                bulldog              [bulldog]                [bulldog]
# 5      nereknu9558285913  [nereknu, 9558285913]  [nere, knu, 9558285913]
# 6                blbysek              [blbysek]                [, , sek]
# 7               123456a7         [123456, a, 7]           [123456, a, 7]
# 8              lumpy1976          [lumpy, 1976]            [lumpy, 1976]
# 9                simonm4            [simonm, 4]            [simon, m, 4]
# 10              kurvicky             [kurvicky]             [kur, vicky]
# 11            MlGqTAZY05         [MlGqTAZY, 05]             [mlgqtazy, ]
# ...

# %%
data['joinwithout2'] = ""
for index, row in data.iterrows():
    row['joinwithout2'] = " ".join(row['extrawordsplit'])

# %%
data
# Out:
#                 original       specialcharsplit           extrawordsplit  \
# 0             V76szXAoQ9     [V, 76, szXAoQ, 9]       [v, , , xao, q, 9]
# 1              milanek22          [milanek, 22]              [milan, , ]
# 2           PancharT1983       [PancharT, 1983]       [pan, chart, 1983]
# 3             pipinka123         [pipinka, 123]         [, pink, a, 123]
# 4                bulldog              [bulldog]                [bulldog]
# 5      nereknu9558285913  [nereknu, 9558285913]  [nere, knu, 9558285913]
# 6                blbysek              [blbysek]                [, , sek]
# 7               123456a7         [123456, a, 7]           [123456, a, 7]
# 8              lumpy1976          [lumpy, 1976]            [lumpy, 1976]
# 9                simonm4            [simonm, 4]            [simon, m, 4]
# 10              kurvicky             [kurvicky]             [kur, vicky]
# 11            MlGqTAZY05         [MlGqTAZY, 05]             [mlgqtazy, ]
# ...

# %%
for index, row in data.iterrows():
    for i, val in enumerate(row['extrawordsplit']):
        if len((row['extrawordsplit'])[i]) == 1:
            (row['extrawordsplit'])[i] = ''

# %%
data['joinwithout2n1'] = ""
for index, row in data.iterrows():
    row['joinwithout2n1'] = " ".join(row['extrawordsplit'])

# %%
data
# Out:
#                 original       specialcharsplit           extrawordsplit  \
# 0             V76szXAoQ9     [V, 76, szXAoQ, 9]          [, , , xao, , ]
# 1              milanek22          [milanek, 22]              [milan, , ]
# 2           PancharT1983       [PancharT, 1983]       [pan, chart, 1983]
# 3             pipinka123         [pipinka, 123]          [, pink, , 123]
# 4                bulldog              [bulldog]                [bulldog]
# 5      nereknu9558285913  [nereknu, 9558285913]  [nere, knu, 9558285913]
# 6                blbysek              [blbysek]                [, , sek]
# 7               123456a7         [123456, a, 7]             [123456, , ]
# 8              lumpy1976          [lumpy, 1976]            [lumpy, 1976]
# 9                simonm4            [simonm, 4]              [simon, , ]
# 10              kurvicky             [kurvicky]             [kur, vicky]
# 11            MlGqTAZY05         [MlGqTAZY, 05]             [mlgqtazy, ]
# ...
